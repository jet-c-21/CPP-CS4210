# %%
import pandas as pd

# %%
df = pd.read_csv('contact_lens.csv')

# %%
df
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 0          Young                  Myope          No              Reduced
# 1     Presbyopic                  Myope          No               Normal
# 2  Prepresbyopic                  Myope          No              Reduced
# 3  Prepresbyopic                  Myope          No               Normal
# 4     Presbyopic                  Myope         Yes               Normal
# 5          Young                  Myope         Yes               Normal
# 6          Young           Hypermetrope          No              Reduced
# 7  Prepresbyopic                  Myope         Yes              Reduced
# 8     Presbyopic           Hypermetrope          No              Reduced
# 9          Young                  Myope         Yes              Reduced
#
#    Recommended Lenses
# 0                  No
# 1                  No
# 2                  No
# 3                 Yes
# 4                 Yes
# 5                 Yes
# ...

# %%
df[df['Age']=='Prepresbyopic']
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 2  Prepresbyopic                  Myope          No              Reduced
# 3  Prepresbyopic                  Myope          No               Normal
# 7  Prepresbyopic                  Myope         Yes              Reduced
#
#    Recommended Lenses
# 2                  No
# 3                 Yes
# 7                  No

# %%
df[df['Age']=='Presbyopic']
# Out:
#           Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 1  Presbyopic                  Myope          No               Normal
# 4  Presbyopic                  Myope         Yes               Normal
# 8  Presbyopic           Hypermetrope          No              Reduced
#
#    Recommended Lenses
# 1                  No
# 4                 Yes
# 8                  No

# %%
df[df['Spectacle Prescription']=='Myope']
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 0          Young                  Myope          No              Reduced
# 1     Presbyopic                  Myope          No               Normal
# 2  Prepresbyopic                  Myope          No              Reduced
# 3  Prepresbyopic                  Myope          No               Normal
# 4     Presbyopic                  Myope         Yes               Normal
# 5          Young                  Myope         Yes               Normal
# 7  Prepresbyopic                  Myope         Yes              Reduced
# 9          Young                  Myope         Yes              Reduced
#
#    Recommended Lenses
# 0                  No
# 1                  No
# 2                  No
# 3                 Yes
# 4                 Yes
# 5                 Yes
# 7                  No
# 9                 Yes

# %%
df[df['Spectacle Prescription']=='Hypermetrope']
# Out:
#           Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 6       Young           Hypermetrope          No              Reduced
# 8  Presbyopic           Hypermetrope          No              Reduced
#
#    Recommended Lenses
# 6                  No
# 8                  No

# %%
df[df['Astigmatism']=='Yes']
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 4     Presbyopic                  Myope         Yes               Normal
# 5          Young                  Myope         Yes               Normal
# 7  Prepresbyopic                  Myope         Yes              Reduced
# 9          Young                  Myope         Yes              Reduced
#
#    Recommended Lenses
# 4                 Yes
# 5                 Yes
# 7                  No
# 9                 Yes

# %%
df[df['Astigmatism']=='No']
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 0          Young                  Myope          No              Reduced
# 1     Presbyopic                  Myope          No               Normal
# 2  Prepresbyopic                  Myope          No              Reduced
# 3  Prepresbyopic                  Myope          No               Normal
# 6          Young           Hypermetrope          No              Reduced
# 8     Presbyopic           Hypermetrope          No              Reduced
#
#    Recommended Lenses
# 0                  No
# 1                  No
# 2                  No
# 3                 Yes
# 6                  No
# 8                  No

# %%
df.loc[
    (df['Tear Production Rate']=='Normal') & 
    (df['Age'] == 'Young')
]
# Out:
#      Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 5  Young                  Myope         Yes               Normal
#
#    Recommended Lenses
# 5                 Yes

# %%
df[df['Tear Production Rate']=='Reduced']
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 0          Young                  Myope          No              Reduced
# 2  Prepresbyopic                  Myope          No              Reduced
# 6          Young           Hypermetrope          No              Reduced
# 7  Prepresbyopic                  Myope         Yes              Reduced
# 8     Presbyopic           Hypermetrope          No              Reduced
# 9          Young                  Myope         Yes              Reduced
#
#    Recommended Lenses
# 0                  No
# 2                  No
# 6                  No
# 7                  No
# 8                  No
# 9                 Yes

# %%
df[df['Tear Production Rate']=='Normal']
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 1     Presbyopic                  Myope          No               Normal
# 3  Prepresbyopic                  Myope          No               Normal
# 4     Presbyopic                  Myope         Yes               Normal
# 5          Young                  Myope         Yes               Normal
#
#    Recommended Lenses
# 1                  No
# 3                 Yes
# 4                 Yes
# 5                 Yes

# %%
df.loc[
    (df['Tear Production Rate']=='Normal') & 
    (df['Age'] == 'Prepresbyopic')
]
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 3  Prepresbyopic                  Myope          No               Normal
#
#    Recommended Lenses
# 3                 Yes

# %%
df.loc[
    (df['Tear Production Rate']=='Normal') & 
    (df['Age'] == 'Presbyopic')
]
# Out:
#           Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 1  Presbyopic                  Myope          No               Normal
# 4  Presbyopic                  Myope         Yes               Normal
#
#    Recommended Lenses
# 1                  No
# 4                 Yes

# %%
df.loc[
    (df['Tear Production Rate']=='Normal') & 
    (df['Spectacle Prescription'] == 'Myope')
]
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 1     Presbyopic                  Myope          No               Normal
# 3  Prepresbyopic                  Myope          No               Normal
# 4     Presbyopic                  Myope         Yes               Normal
# 5          Young                  Myope         Yes               Normal
#
#    Recommended Lenses
# 1                  No
# 3                 Yes
# 4                 Yes
# 5                 Yes

# %%
df.loc[
    (df['Tear Production Rate']=='Normal') & 
    (df['Astigmatism'] == 'Yes')
]
# Out:
#           Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 4  Presbyopic                  Myope         Yes               Normal
# 5       Young                  Myope         Yes               Normal
#
#    Recommended Lenses
# 4                 Yes
# 5                 Yes

# %%
df.loc[
    (df['Tear Production Rate']=='Normal') & 
    (df['Astigmatism'] == 'No')
]
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 1     Presbyopic                  Myope          No               Normal
# 3  Prepresbyopic                  Myope          No               Normal
#
#    Recommended Lenses
# 1                  No
# 3                 Yes

# %%
df.loc[
    (df['Tear Production Rate']=='Reduced')
]
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 0          Young                  Myope          No              Reduced
# 2  Prepresbyopic                  Myope          No              Reduced
# 6          Young           Hypermetrope          No              Reduced
# 7  Prepresbyopic                  Myope         Yes              Reduced
# 8     Presbyopic           Hypermetrope          No              Reduced
# 9          Young                  Myope         Yes              Reduced
#
#    Recommended Lenses
# 0                  No
# 2                  No
# 6                  No
# 7                  No
# 8                  No
# 9                 Yes

# %%
df.loc[
    (df['Tear Production Rate']=='Reduced') & 
    (df['Astigmatism'] == 'Yes')
]
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 7  Prepresbyopic                  Myope         Yes              Reduced
# 9          Young                  Myope         Yes              Reduced
#
#    Recommended Lenses
# 7                  No
# 9                 Yes

# %%
df.loc[
    (df['Tear Production Rate']=='Reduced') & 
    (df['Astigmatism'] == 'No')
]
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 0          Young                  Myope          No              Reduced
# 2  Prepresbyopic                  Myope          No              Reduced
# 6          Young           Hypermetrope          No              Reduced
# 8     Presbyopic           Hypermetrope          No              Reduced
#
#    Recommended Lenses
# 0                  No
# 2                  No
# 6                  No
# 8                  No

# %%
df.loc[
    (df['Tear Production Rate']=='Reduced') & 
    (df['Age'] == 'Young')
]
# Out:
#      Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 0  Young                  Myope          No              Reduced
# 6  Young           Hypermetrope          No              Reduced
# 9  Young                  Myope         Yes              Reduced
#
#    Recommended Lenses
# 0                  No
# 6                  No
# 9                 Yes

# %%
df.loc[
    (df['Tear Production Rate']=='Normal') & 
    (df['Age'] == 'Young')
]
# Out:
#      Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 5  Young                  Myope         Yes               Normal
#
#    Recommended Lenses
# 5                 Yes

# %%
df.loc[
    (df['Tear Production Rate']=='Normal') &
    (df['Age'] == 'Presbyopic')
]
# Out:
#           Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 1  Presbyopic                  Myope          No               Normal
# 4  Presbyopic                  Myope         Yes               Normal
#
#    Recommended Lenses
# 1                  No
# 4                 Yes

# %%
df.loc[
    (df['Tear Production Rate']=='Normal') &
    (df['Age'] == 'Prepresbyopic')
]
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 3  Prepresbyopic                  Myope          No               Normal
#
#    Recommended Lenses
# 3                 Yes

# %%
df.loc[
    (df['Tear Production Rate']=='Normal') &
    (df['Age'] == 'Presbyopic')
]
# Out:
#           Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 1  Presbyopic                  Myope          No               Normal
# 4  Presbyopic                  Myope         Yes               Normal
#
#    Recommended Lenses
# 1                  No
# 4                 Yes

# %%
df.loc[
    (df['Tear Production Rate']=='Reduced') &
    (df['Astigmatism'] == 'Yes')
]
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 7  Prepresbyopic                  Myope         Yes              Reduced
# 9          Young                  Myope         Yes              Reduced
#
#    Recommended Lenses
# 7                  No
# 9                 Yes

# %%
df.loc[
    (df['Tear Production Rate']=='Reduced') &
    (df['Astigmatism'] == 'No')
]
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 0          Young                  Myope          No              Reduced
# 2  Prepresbyopic                  Myope          No              Reduced
# 6          Young           Hypermetrope          No              Reduced
# 8     Presbyopic           Hypermetrope          No              Reduced
#
#    Recommended Lenses
# 0                  No
# 2                  No
# 6                  No
# 8                  No

# %%
df.loc[
    (df['Tear Production Rate']=='Normal') &
    (df['Astigmatism'] == 'No')
]
# Out:
#              Age Spectacle Prescription Astigmatism Tear Production Rate  \
# 1     Presbyopic                  Myope          No               Normal
# 3  Prepresbyopic                  Myope          No               Normal
#
#    Recommended Lenses
# 1                  No
# 3                 Yes
